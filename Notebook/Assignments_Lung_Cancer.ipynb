# %%
##Importing necessary Python Libreries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

# %%
##Importing data and converting data from csv to DataFrame
df = pd.read_csv('/Data/dataset.csv')

# %%
##Showing basic information about the dataset
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   65        1               1        1              2
# 1      F   55        1               2        2              1
# 2      F   78        2               2        1              1
# 3      M   60        2               1        1              1
# 4      F   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN LUNG_CANCER
# ...

# %%
#understanding the shape of the data
df.shape
# Out:
# (3000, 16)

# %%
#understanding some inforamation about dataset and datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 3000 non-null   object
#  1   AGE                    3000 non-null   int64
#  2   SMOKING                3000 non-null   int64
#  3   YELLOW_FINGERS         3000 non-null   int64
#  4   ANXIETY                3000 non-null   int64
#  5   PEER_PRESSURE          3000 non-null   int64
#  6   CHRONIC_DISEASE        3000 non-null   int64
#  7   FATIGUE                3000 non-null   int64
#  8   ALLERGY                3000 non-null   int64
#  9   WHEEZING               3000 non-null   int64
#  10  ALCOHOL_CONSUMING      3000 non-null   int64
#  11  COUGHING               3000 non-null   int64
#  12  SHORTNESS_OF_BREATH    3000 non-null   int64
#  13  SWALLOWING_DIFFICULTY  3000 non-null   int64
#  14  CHEST_PAIN             3000 non-null   int64
# ...

# %%
#understanding the statistiacl understanding the dataset
df.describe()
# Out:
#                AGE      SMOKING  YELLOW_FINGERS      ANXIETY  PEER_PRESSURE  \
# count  3000.000000  3000.000000     3000.000000  3000.000000    3000.000000
# mean     55.169000     1.491000        1.514000     1.494000       1.499000
# std      14.723746     0.500002        0.499887     0.500047       0.500082
# min      30.000000     1.000000        1.000000     1.000000       1.000000
# 25%      42.000000     1.000000        1.000000     1.000000       1.000000
# 50%      55.000000     1.000000        2.000000     1.000000       1.000000
# 75%      68.000000     2.000000        2.000000     2.000000       2.000000
# max      80.000000     2.000000        2.000000     2.000000       2.000000
#
#        CHRONIC_DISEASE      FATIGUE      ALLERGY     WHEEZING  \
# count      3000.000000  3000.000000  3000.000000  3000.000000
# mean          1.509667     1.489667     1.506667     1.497333
# std           0.499990     0.499977     0.500039     0.500076
# ...

# %%
##Checcking dataset if there is any null value is there or not
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC_DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL_CONSUMING        0
# COUGHING                 0
# SHORTNESS_OF_BREATH      0
# SWALLOWING_DIFFICULTY    0
# CHEST_PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %%
#So it clear obsereved that no null values are present in the data sets

# %%
#Checking data set if there is any duplicate value is there or not
df.duplicated().sum()
# Out:
# 2

# %%
#2 duplicate values are found
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2998, 16)

# %%
#we have 2 categorical collumn (Gender and lung_cancer) so here we do level encoding for smooth EDA
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['GENDER'] = le.fit_transform(df['GENDER'])
df['LUNG_CANCER'] = le.fit_transform(df['LUNG_CANCER'])

# %%
df
# Out:
#       GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0          1   65        1               1        1              2
# 1          0   55        1               2        2              1
# 2          0   78        2               2        1              1
# 3          1   60        2               1        1              1
# 4          0   80        1               1        2              1
# ...      ...  ...      ...             ...      ...            ...
# 2995       0   71        2               1        1              2
# 2996       0   75        1               2        1              1
# 2997       0   62        2               2        2              1
# 2998       1   30        1               1        2              2
# 2999       1   40        1               2        2              1
#
#       CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  \
# 0                   2        1        2         2                  2
# ...

# %%
df.head()
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       1   65        1               1        1              2
# 1       0   55        1               2        2              1
# 2       0   78        2               2        1              1
# 3       1   60        2               1        1              1
# 4       0   80        1               1        2              1
#
#    CHRONIC_DISEASE  FATIGUE  ALLERGY  WHEEZING  ALCOHOL_CONSUMING  COUGHING  \
# 0                2        1        2         2                  2         2
# 1                1        2        2         2                  1         1
# 2                1        2        1         2                  1         1
# 3                2        1        2         1                  1         2
# 4                1        2        1         2                  1         1
#
#    SHORTNESS_OF_BREATH  SWALLOWING_DIFFICULTY  CHEST_PAIN  LUNG_CANCER
# ...

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
con_col = ['AGE']
cat_col=[]
for i in df.columns:
    if i!='AGE':
        cat_col.append(i)

# %%
cat_col
# Out:
# ['GENDER',
#  'SMOKING',
#  'YELLOW_FINGERS',
#  'ANXIETY',
#  'PEER_PRESSURE',
#  'CHRONIC_DISEASE',
#  'FATIGUE',
#  'ALLERGY',
#  'WHEEZING',
#  'ALCOHOL_CONSUMING',
#  'COUGHING',
#  'SHORTNESS_OF_BREATH',
#  'SWALLOWING_DIFFICULTY',
#  'CHEST_PAIN',
#  'LUNG_CANCER']

# %%
df.corr()
# Out:
#                          GENDER       AGE   SMOKING  YELLOW_FINGERS   ANXIETY  \
# GENDER                 1.000000  0.011134 -0.027873        0.014440 -0.023914
# AGE                    0.011134  1.000000 -0.020459        0.016034  0.029996
# SMOKING               -0.027873 -0.020459  1.000000       -0.001516 -0.055591
# YELLOW_FINGERS         0.014440  0.016034 -0.001516        1.000000  0.011683
# ANXIETY               -0.023914  0.029996 -0.055591        0.011683  1.000000
# PEER_PRESSURE          0.009363  0.004018 -0.031405        0.011420 -0.024717
# CHRONIC_DISEASE        0.008507 -0.025735  0.045715       -0.013892  0.016247
# FATIGUE                0.002181 -0.002251  0.019662       -0.010100 -0.005587
# ALLERGY                0.013890  0.024755  0.004247       -0.005732 -0.001166
# WHEEZING              -0.009294 -0.018150  0.000575        0.004821 -0.015409
# ALCOHOL_CONSUMING     -0.009191 -0.020640  0.003036        0.027853 -0.000876
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,fmt='0.2f')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,15))
sns.pairplot(df)

# %%
sns.histplot(data=df, x='AGE',hue='LUNG_CANCER',kde=True,palette='deep',multiple='stack')
# Out:
# <Axes: xlabel='AGE', ylabel='Count'>

# %%
sns.histplot(data=df, x='SMOKING',hue='LUNG_CANCER',kde=True,palette='deep',multiple='stack')
# Out:
# <Axes: xlabel='SMOKING', ylabel='Count'>
